# %%
import numpy as np
from typing import List
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import TweetTokenizer

import re

from scipy.spatial.distance import cosine

from matplotlib import pyplot as plt
import seaborn as sns

# %%
def preprocessor(text: str) -> str:
    text = re.sub(r'[!\"#$%&\'()*\+,-./:;<=>?@\[\\\]^_`{|}~]+', ' ', text.lower())
    text = text.replace('ё', 'е')
    return text


def stemm_tokenizer(text: str, stemmer, tknzr) -> str:
    cleaned_text = preprocessor(text)
    stemmed_text = ' '.join([stemmer.stem(w) for w in tknzr.tokenize(cleaned_text) if w.isalpha()])
    return stemmed_text

# %%
def f1_score(precision_list, recall_list):
    prec = np.array(precision_list)
    rec = np.array(recall_list)
    f1 = 2 * prec * rec / (prec + rec)
    return f1

# %%
# %run experiment_template.py
# %run loss.py

# %%
stemmer = SnowballStemmer('russian')
tokenizer = TweetTokenizer()

tfidf = TfidfVectorizer(max_df=0.3,
                        min_df=3,
                       tokenizer=lambda text: stemm_tokenizer(text, stemmer, tokenizer).split())

# %%
data = pd.read_csv('../data/test_data.csv') # выгружаем датасет новостей
data = data[~data['text'].isna()]

# %%
tfidf.fit(data.text)
# Out:
# C:\Users\Sergei\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:484: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# TfidfVectorizer(max_df=0.3, min_df=3,
#                 tokenizer=<function <lambda> at 0x0000017A198681F0>)

# %%
comm_res = pd.read_csv('../data/toloka_result_pairs.csv')
valid_inds = np.union1d(comm_res['new_1'].values, comm_res['new_2'].values)
comm_res = comm_res.groupby(['new_1', 'new_2']).max()
        
comm_res_train, comm_res_test, _, _ = train_test_split(comm_res, comm_res, train_size=0.5, random_state=42)

# %%
myexp = MyExperiment(data.loc[valid_inds], tfidf, 'Cos_Last',0.9)

# %%
myexp.run()
# Out:
# Succesful run

# %%
myexp.info()
# Out:
# {'Specification': 'Cos_Last', 'Threshold': 0.1, 'Num of news': 2992, 'Num of chains': 2991, 'Max chain length': 2, 'Min chain length': 1, 'Chains': [array([2], dtype=int64), array([3], dtype=int64), array([9], dtype=int64), array([10], dtype=int64), array([11], dtype=int64), array([19], dtype=int64), array([22], dtype=int64), array([24], dtype=int64), array([26], dtype=int64), array([34], dtype=int64), array([47], dtype=int64), array([48], dtype=int64), array([49], dtype=int64), array([51], dtype=int64), array([53], dtype=int64), array([57], dtype=int64), array([58], dtype=int64), array([68], dtype=int64), array([80], dtype=int64), array([81], dtype=int64), array([82], dtype=int64), array([88], dtype=int64), array([89], dtype=int64), array([90], dtype=int64), array([97], dtype=int64), array([98], dtype=int64), array([107], dtype=int64), array([112], dtype=int64), array([113], dtype=int64), array([120], dtype=int64), array([125], dtype=int64), array([127], dtype=int64), array([130], dtype=int64), array([141], dtype=int64), array([143], dtype=int64), array([144], dtype=int64), array([149], dtype=int64), array([150], dtype=int64), array([152], dtype=int64), array([154], dtype=int64), array([156], dtype=int64), array([157], dtype=int64), array([159], dtype=int64), array([160], dtype=int64), array([174], dtype=int64), array([175], dtype=int64), array([183], dtype=int64), array([186], dtype=int64), array([189], dtype=int64), array([190], dtype=int64), array([192], dtype=int64), array([197], dtype=int64), array([198], dtype=int64), array([199], dtype=int64), array([212], dtype=int64), array([220], dtype=int64), array([221], dtype=int64), array([224], dtype=int64), array([230], dtype=int64), array([231], dtype=int64), array([243], dtype=int64), array([251], dtype=int64), array([252], dtype=int64), array([253], dtype=int64), array([257], dtype=int64), array([260], dtype=int64), array([264], dtype=int64), array([266], dtype=int64), array([267], dtype=int64), array([268], dtype=int64), array([269], dtype=int64), array([272], dtype=int64), array([279], dtype=int64), array([285], dtype=int64), array([290], dtype=int64), array([292], dtype=int64), array([298], dtype=int64), array([301], dtype=int64), array([304], dtype=int64), array([305], dtype=int64), array([315], dtype=int64), array([319], dtype=int64), array([320], dtype=int64), array([327], dtype=int64), array([332], dtype=int64), array([338], dtype=int64), array([341], dtype=int64), array([348], dtype=int64), array([349], dtype=int64), array([355], dtype=int64), array([356], dtype=int64), array([357], dtype=int64), array([359], dtype=int64), array([360], dtype=int64), array([363], dtype=int64), array([367], dtype=int64), array([368], dtype=int64), array([371], dtype=int64), array([372], dtype=int64), array([374], dtype=int64), array([375], dtype=int64), array([380], dtype=int64), array([382], dtype=int64), array([383], dtype=int64), array([386], dtype=int64), array([388], dtype=int64), array([390], dtype=int64), array([391], dtype=int64), array([396], dtype=int64), array([397], dtype=int64), array([401], dtype=int64), array([405], dtype=int64), array([406], dtype=int64), array([408], dtype=int64), array([409], dtype=int64), array([413], dtype=int64), array([416], dtype=int64), array([423], dtype=int64), array([424], dtype=int64), array([432], dtype=int64), array([435], dtype=int64), array([437], dtype=int64), array([443], dtype=int64), array([445], dtype=int64), array([447], dtype=int64), array([452], dtype=int64), array([456], dtype=int64), array([457], dtype=int64), array([463], dtype=int64), array([465], dtype=int64), array([471], dtype=int64), array([473], dtype=int64), array([476], dtype=int64), array([479], dtype=int64), array([481], dtype=int64), array([491], dtype=int64), array([495], dtype=int64), array([497], dtype=int64), array([498], dtype=int64), array([499], dtype=int64), array([500], dtype=int64), array([505], dtype=int64), array([507], dtype=int64), array([516], dtype= ...

# %%
myexp.evaluate()
# Out:
# Result of evaluation:
# Train precision: 0.4371973796639134
# Train Recall:1.0
# Test Precision:0.4347949886104784
# TestRecall:1.0

# %%
myexp.run(0.1)
# Out:
# Succesful run

# %%
myexp.evaluate()
# Out:
# Result of evaluation:
# Train precision: 1.0
# Train Recall:0.004560260586319218
# Test Precision:0.5
# TestRecall:0.0006548788474132286
